# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("C:/Users/User/Documents/DATA ANALYST/MeriSKILL Projects/HR-Employee-Attrition.csv")

# %%
#Top 5 rows
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#Last 5 rows
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#Dimensions of df
df.shape
# Out:
# (1470, 35)

# %%
#Summary of df
df.info
# Out:
# <bound method DataFrame.info of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
#colums of df
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#null values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Dropping duplicates
df = df.drop_duplicates()
#Dropping Nan Values
df = df.dropna()

# %%
#Showing a correlation map for all numeric variables
corr_matrix = df.corr()
plt.figure(figsize= (20,10))
sns.heatmap(corr_matrix, annot=True, cmap= 'coolwarm')
plt.title('Correlation map for numeric variables')
plt.show()

# %% [markdown]
# Visualize categorical Variables

# %%
data = df

# %%
#Overtime
sns.countplot(data, x='OverTime')
plt.title('OverTime')
plt.show()

# %%
#Marital Status
sns.countplot(data, x='MaritalStatus')
plt.title('Marital Status')
plt.show()

# %%
#JobRole
plt.figure(figsize=(10,5))
sns.countplot(data, y='JobRole')
plt.title('JobRole')
plt.show()

# %%
#Gender
sns.countplot(data, x='Gender')
plt.title('Gender')
plt.show()

# %%
#Education Field
plt.figure(figsize=(10,5))
sns.countplot(data, y='EducationField')
plt.title('EducationField')
plt.show()

# %%
#Department
sns.countplot(data, x='Department')
plt.title('Department')
plt.show()

# %%
#Business Travel
sns.countplot(data, x='BusinessTravel')
plt.title('Business Travel')
plt.show()

# %%
#Relationship Between Overtime and Age
plt.figure(figsize=(10,5))
sns.boxplot(data, x='OverTinme', y='Age')
plt.title('Relationship Between Overtime and Age')
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# Plotting Numerical Variables

# %%
#Total Working Years
sns.histplot(data, x='TotalWorkingYears',bins=10, kde=True)
plt.title('Total Working Hours')
plt.show()

# %%
#Education Level
sns.histplot(data, x='Education',bins=10, kde=True)
plt.title('Education Level')
plt.show()

# %%
#Number of Companies Worked
sns.histplot(data, x='NumCompaniesWorked',bins=10, kde=True)
plt.title('Number of Companies Worked')
plt.show()

# %%
#Distance From Home
sns.histplot(data, x='DistanceFromHome',bins=10, kde=True)
plt.title('Distance From Home')
plt.show()

# %% [markdown]
# Salary Analysis

# %%
#Monthly Income Distribution
sns.histplot(data, x='MonthlyIncome',bins=10, kde=True)
plt.title('Monthly Income Distribution')
plt.show()

# %%
#Salary by Job Role
plt.figure(figsize=(10,5))
sns.boxplot(data, x='JobRole', y= 'MonthlyIncome')
plt.title('Salary by Job Role')
plt.xticks(rotation = 50)
plt.show()

# %% [markdown]
# Employee Satisfaction and Performance

# %%
#Job Satisfaction Distribution
sns.histplot(data, x='JobSatisfaction',bins=10, kde=True)
plt.title('Job Satisfaction Distribution')
plt.show()

# %%
#Performance Rating Distribution
sns.histplot(data, x='PerformanceRating',bins=10, kde=True)
plt.title('Performance Rating Distribution')
plt.show()

# %%
#Employee Tenure Distribution
sns.histplot(data, x='YearsAtCompany',bins=10, kde=True)
plt.title('Employee Tenure Distribution')
plt.show()

# %%
#Age Distribution by Department
plt.figure(figsize=(10,6))
sns.boxplot(data, x='Department', y= 'Age')
plt.title('Age Distribution by Department')
plt.show()

# %%
#Attrition by Job Role
plt.figure(figsize=(10,5))
sns.countplot(data, x='JobRole', hue= 'Attrition')
plt.title('Attrition by Job Role')
plt.xticks(rotation = 50)
plt.show()
